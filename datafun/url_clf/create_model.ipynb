# %%
from sklearn.model_selection import train_test_split
from sklearn.externals import joblib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
import pandas as pd
import numpy as np
import random
from mylib import tokenize as tk

# %% [markdown]
# ## Read data from .csv file

# %%
dataset_path = 'dataset.csv'    # path to our all urls file
dataset = pd.read_csv(dataset_path,sep=',',encoding='utf-8', error_bad_lines=False)    # reading file
df = pd.DataFrame(dataset)    # converting to a dataframe

df    # print
# Out:
#                                                       url label
# 0                                  diaryofagameaddict.com   bad
# 1                                        espdesign.com.au   bad
# 2                                      iamagameaddict.com   bad
# 3                                           kalantzis.net   bad
# 4                                   slightlyoffcenter.net   bad
# 5                                        toddscarwash.com   bad
# 6                                          tubemoviez.com   bad
# 7                                                  ipl.hk   bad
# 8             crackspider.us/toolbar/install.php?pack=exe   bad
# 9                                         pos-kupang.com/   bad
# 10                                             rupor.info   bad
# 11      svision-online.de/mgfi/administrator/component...   bad
# 12      officeon.ch.ma/office.js?google_ad_format=728x...   bad
# 13                                            sn-gzzx.com   bad
# 14                          sunlux.net/company/about.html   bad
# 15                                            outporn.com   bad
# 16                                 timothycopus.aimoo.com   bad
# 17                                        xindalawyer.com   bad
# 18                       freeserials.spb.ru/key/68703.htm   bad
# 19                               deletespyware-adware.com   bad
# 20                        orbowlada.strefa.pl/text396.htm   bad
# 21                                          ruiyangcn.com   bad
# 22                                               zkic.com   bad
# 23      adserving.favorit-network.com/eas?camp=19320;c...   bad
# 24                                       cracks.vg/d1.php   bad
# 25                                    juicypussyclips.com   bad
# 26                                      nuptialimages.com   bad
# 27                                          andysgame.com   bad
# 28                                         bezproudoff.cz   bad
# 29                                     ceskarepublika.net   bad
# ...                                                   ...   ...
# 420434                   www.alfalima.it/transactions.php   bad
# 420435         rapiseebrains.com/?a=401336&c=cpc&s=050217   bad
# 420436  fuji-ncb.com.pk/js/fancybox/autolink/mailbox/m...   bad
# 420437                                aadroid.net/sys.olk   bad
# 420438               mit.fileserver4390.org/file/nost.bgt   bad
# 420439                     cureeczemafast.org/wp-conf.gbn   bad
# 420440                      glutenfreeworks.com/lftAd.vfd   bad
# 420441                 dataplues.com/quincy/pony/gate.php   bad
# 420442                                      60.250.76.52/   bad
# 420443                                        f4321y.com/   bad
# 420444                                        mykings.pw/   bad
# 420445  activatemywebsetup.com/img/sunday/Excel/PO/pag...   bad
# 420446             www.iemailpremium.com/read.php?f=1.gif   bad
# 420447                             highpowerresources.com   bad
# 420448  new.ASKGRANNYSHOP.COM/?ct=Vivaldi&amp;q=w33QMv...   bad
# 420449  find.burnsmarketingandresearch.com/?br_fl=6042...   bad
# 420450  gfd.DATINGUPPERCLASS.COM/?biw=Microsoft_Edge.7...   bad
# 420451  rty.freebiesfortheover60s.com/?biw=Amaya.102tw...   bad
# 420452          defibel.org/wp-includes/images/index.html   bad
# 420453  stefanocardone.com/wp-includes/SimplePie/HTTP/...   bad
# 420454          defibel.org/wp-includes/images/index.html   bad
# 420455  shapingsoftware.com/2009/02/09/architectural-s...   bad
# 420456  free.ulohapp.info/?br_fl=2872&amp;tuif=5539&am...   bad
# 420457  free.ulohapp.info/?oq=CEh3h_PskJLFZaQWwjEKBegU...   bad
# 420458                        mol.com-ho.me/cv_itworx.doc   bad
# 420459                                    23.227.196.215/   bad
# 420460                                 apple-checker.org/   bad
# 420461                                  apple-iclods.org/   bad
# 420462                                 apple-uptoday.org/   bad
# 420463                                  apple-search.info   bad
#
# [420464 rows x 2 columns]

# %%
df = np.array(df)    # converting it into an array
random.shuffle(df)    # shuffling

# %%
target = [d[1] for d in df]    # all labels
corpus = [d[0] for d in df]    # all urls corresponding to a label (either good or bad)

# %% [markdown]
# # TF-IDF

# %%
vect = TfidfVectorizer(tokenizer=tk, max_features=1000)    # get a vector for each url but use our customized tokenizer
corpus_vect = vect.fit_transform(corpus)    # get the corpus vector

vect.get_feature_names()
# Out:
# ['',
#  '%20secure%20login_files',
#  "'",
#  '.https',
#  '0',
#  '0001',
#  '001',
#  '01',
#  '02',
#  '03',
#  '04',
#  '05',
#  '06',
#  '07',
#  '08',
#  '09',
#  '0secure0login_files',
#  '1',
#  '1&amp;email=&amp;',
#  '1&amp;fav',
#  '1&amp;rand',
#  '1&email=&',
#  '1&fav',
#  '1&rand',
#  "1'",
#  "1.html'",
#  '10',
#  '11',
#  '12',
#  '1252899642&amp;fid',
#  '1252899642&amp;fid=1&amp;fav',
#  '1252899642&fid',
#  '1252899642&fid=1&fav',
#  '1252899642=&amp;fid',
#  '13',
#  '13inboxlight',
#  '14',
#  '15',
#  '16',
#  '160624',
#  '163',
#  '17',
#  '1774256418&amp;fid',
#  '1774256418&amp;rand',
#  '1774256418&fid',
#  "1774256418'",
#  '18',
#  '19',
#  '1=&amp;fid',
#  '2',
#  "2'",
#  '20',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2015',
#  '2016',
#  '21',
#  '22',
#  '23',
#  '24',
#  '25',
#  '26',
#  '27',
#  '28',
#  '29',
#  '3',
#  '30',
#  '31',
#  '4',
#  '5',
#  '6',
#  '7',
#  '8',
#  '80port',
#  '9',
#  '?http:',
#  '?ref=http:',
#  '?us',
#  '?us.battle.net',
#  '_',
#  'a',
#  'about',
#  'ac',
#  'access',
#  'account',
#  'accounts',
#  'acesso',
#  'actor',
#  'actors',
#  'ad',
#  'admin',
#  'administrator',
#  'adobe',
#  'ae',
#  'al',
#  'album',
#  'albums',
#  'ali',
#  'alibaba',
#  'all',
#  "all.html'",
#  'almanac',
#  'almanac.com',
#  'amazon',
#  'ameli',
#  'america',
#  'american',
#  'an',
#  'ancestry',
#  'and',
#  'angeles',
#  'answers',
#  'aol',
#  'app',
#  'apple',
#  'appmanager',
#  'ar',
#  'arch',
#  'archive',
#  'archives',
#  'are',
#  'area',
#  'art',
#  'article',
#  'articles',
#  'artist',
#  'artists',
#  'arts',
#  'as',
#  "ashx'",
#  'ask',
#  "asp'",
#  'aspx',
#  "aspx'",
#  "aspx?n=1774256418&amp;fid=4'",
#  "aspx?n=1774256418&fid=4#n=1252899642&fid=1&fav=1'",
#  "aspx?n=1774256418'",
#  'aspxn',
#  'assets',
#  'assure_somtc=true',
#  'at',
#  'atendimento',
#  'athletics',
#  'atoz',
#  'au',
#  'auth',
#  'author',
#  'auto',
#  'avi',
#  'b',
#  "b'123people",
#  "b'123people.ca",
#  "b'123people.com",
#  "b'192",
#  "b'192.com",
#  "b'absoluteastronomy",
#  "b'absoluteastronomy.com",
#  "b'acronyms",
#  "b'acronyms.thefreedictionary.com",
#  "b'amazon",
#  "b'amazon.com",
#  "b'answers",
#  "b'answers.com",
#  "b'answers.yahoo.com",
#  "b'archive",
#  "b'archive.org",
#  "b'archiver",
#  "b'archiver.rootsweb.ancestry.com",
#  "b'article",
#  "b'article.wn.com",
#  "b'articles",
#  "b'articles.latimes.com",
#  "b'articles.sfgate.com",
#  "b'au",
#  "b'baseball",
#  "b'bleacherreport",
#  "b'bleacherreport.com",
#  "b'blog",
#  "b'blogs",
#  "b'boards",
#  "b'boards.ancestry.com",
#  "b'btjunkie",
#  "b'btjunkie.org",
#  "b'ca",
#  "b'ca.linkedin.com",
#  "b'ca.ratemyteachers.com",
#  "b'canada",
#  "b'citizendia",
#  "b'citizendia.org",
#  "b'city",
#  "b'classmates",
#  "b'classmates.com",
#  "b'cndoubleegret",
#  "b'cndoubleegret.com",
#  "b'commons",
#  "b'commons.wikimedia.org",
#  "b'connect",
#  "b'connect.in.com",
#  "b'content",
#  "b'content.usatoday.com",
#  "b'corporationwiki",
#  "b'corporationwiki.com",
#  "b'dbpedia",
#  "b'dictionary",
#  "b'dictionary.sensagent.com",
#  "b'directxex",
#  "b'directxex.com",
#  "b'discogs",
#  "b'discogs.com",
#  "b'dl",
#  "b'dl.downf468.com",
#  "b'docstoc",
#  "b'docstoc.com",
#  "b'duckduckgo",
#  "b'duckduckgo.com",
#  "b'e",
#  "b'ebay",
#  "b'ebay.com",
#  "b'en",
#  "b'en.goldenmap.com",
#  "b'en.wikipedia.org",
#  "b'encyclopedia",
#  "b'encyclopedia2",
#  "b'encyclopedia2.thefreedictionary.com",
#  "b'english",
#  "b'english.turkcebilgi.com",
#  "b'espn",
#  "b'espn.go.com",
#  "b'evri",
#  "b'evri.com",
#  "b'ezinearticles",
#  "b'ezinearticles.com",
#  "b'facebook",
#  "b'facebook.com",
#  "b'familytreemaker",
#  "b'familytreemaker.genealogy.com",
#  "b'finance",
#  "b'finance.yahoo.com",
#  "b'flickr",
#  "b'flickr.com",
#  "b'forum",
#  "b'forums",
#  "b'freebase",
#  "b'freebase.com",
#  "b'freepages",
#  "b'freepages.genealogy.rootsweb.ancestry.com",
#  "b'genforum",
#  "b'genforum.genealogy.com",
#  "b'groups",
#  "b'home",
#  "b'homepages",
#  "b'homepages.rootsweb.ancestry.com",
#  "b'http:",
#  "b'icehockey",
#  "b'icehockey.wikia.com",
#  "b'imdb",
#  "b'imdb.com",
#  "b'itunes",
#  "b'itunes.apple.com",
#  "b'kansascity",
#  "b'kf25zx",
#  "b'kf25zx.com",
#  "b'last",
#  "b'last.fm",
#  "b'legacy",
#  "b'legacy.com",
#  "b'linkedin",
#  "b'linkedin.com",
#  "b'living4u",
#  "b'living4u.80port.net",
#  "b'local",
#  "b'local.yahoo.com",
#  "b'mail",
#  "b'manta",
#  "b'manta.com",
#  "b'montreal",
#  "b'movies",
#  "b'movies.nytimes.com",
#  "b'movies.yahoo.com",
#  "b'music",
#  "b'music.yahoo.com",
#  "b'mylife",
#  "b'mylife.com",
#  "b'myspace",
#  "b'myspace.com",
#  "b'names",
#  "b'names.whitepages.com",
#  "b'new",
#  "b'news",
#  "b'paypal",
#  "b'people",
#  "b'people.famouswhy.com",
#  "b'pipl",
#  "b'pipl.com",
#  "b'search",
#  "b'secure",
#  "b'sports",
#  "b'sports.espn.go.com",
#  "b'sports.yahoo.com",
#  "b'sportsillustrated",
#  "b'sportsillustrated.cnn.com",
#  "b'surubiproducciones",
#  "b'surubiproducciones.com",
#  "b'twitter",
#  "b'twitter.com",
#  "b'uk",
#  "b'uk.ask.com",
#  "b'uk.linkedin.com",
#  "b'vimeo",
#  "b'vimeo.com",
#  "b'wc",
#  "b'wc.rootsweb.ancestry.com",
#  "b'web",
#  "b'webmail",
#  "b'webmail.mhcable.com",
#  "b'wiki",
#  "b'wiki.answers.com",
#  "b'wn",
#  "b'wn.com",
#  "b'youtube",
#  "b'youtube.com",
#  'band',
#  'bandcamp',
#  'bank',
#  'baseball',
#  'basketball',
#  'battle',
#  'bay',
#  'bd',
#  'be',
#  'best',
#  'big',
#  'bill',
#  'bin',
#  'bio',
#  "bio'",
#  'biography',
#  'biz',
#  'black',
#  'blog',
#  'blogs',
#  'blogspot',
#  'blue',
#  'board',
#  'bob',
#  'book',
#  'bookmark',
#  'books',
#  'box',
#  'boxun4',
#  'br',
#  'browse',
#  'business',
#  'by',
#  'c',
#  'ca',
#  'cache',
#  'california',
#  'cameo',
#  'can',
#  'canada',
#  'canadian',
#  'card',
#  'casts',
#  'catalog',
#  'category',
#  'cc',
#  'cd',
#  'celebrities',
#  'celebrity',
#  'center',
#  "cfm'",
#  'cgi',
#  'ch',
#  'charles',
#  'cheditor4',
#  'chicago',
#  'cities',
#  'city',
#  'citysearch',
#  'cl',
#  'cli',
#  'client',
#  'clients',
#  'club',
#  'cmd',
#  'cms',
#  'cn',
#  'cnn',
#  'co',
#  'college',
#  'colors',
#  'com',
#  'com&amp;',
#  "com'",
#  'community',
#  'companies',
#  'company',
#  'components',
#  'config',
#  'confirm',
#  'contact',
#  'content',
#  'county',
#  'craigslist',
#  'credit',
#  'css',
#  'cup',
#  'cx',
#  'cz',
#  'd',
#  'd3',
#  "d3'",
#  'data',
#  'data.com',
#  'david',
#  'day',
#  'db',
#  'ddns',
#  'de',
#  'default',
#  'detail',
#  'details',
#  'dhl',
#  'dir',
#  'directory',
#  'disney',
#  'dk',
#  'dnset',
#  'do',
#  'doc',
#  'docs',
#  'docsign',
#  'document',
#  'documents',
#  'dog',
#  "dog.avi.exe'",
#  'domain',
#  'down',
#  'downf468',
#  'download',
#  'downloader',
#  'dp',
#  'dpbx',
#  'dr',
#  'draft',
#  'drive',
#  'drop',
#  'dropbox',
#  "dropbox'",
#  'dropbox2016',
#  'dvd',
#  'dxx',
#  'e',
#  'ebay',
#  'ed',
#  'edu',
#  'email',
#  'en',
#  'encyclopedia',
#  'eng',
#  'english',
#  'entertainment',
#  'error',
#  'errors',
#  'es',
#  'espn',
#  'eu',
#  'event',
#  'events',
#  'excel',
#  "exe'",
#  'f',
#  'facebook',
#  'faculty',
#  'family',
#  'famouswhy',
#  'file',
#  'file.index.htm',
#  'files',
#  'filewords',
#  'film',
#  'films',
#  'finance',
#  'first',
#  'fm',
#  'folder',
#  'fonts',
#  'foodpages',
#  'football',
#  'for',
#  'form',
#  'forum',
#  'forums',
#  'fr',
#  'frank',
#  'free',
#  'freemobile',
#  'from',
#  'fucked',
#  'g',
#  'gallery',
#  'game',
#  'games',
#  'gb',
#  'gb.facebook.com',
#  'gc',
#  'gd',
#  'gdoc',
#  'gdoccc',
#  'gdocs',
#  'genealogy',
#  'general',
#  'george',
#  'girl',
#  'gmail',
#  'go',
#  'gold',
#  'goldenmap',
#  'google',
#  'googledoc',
#  'googledocs',
#  'googledrive',
#  'gouv',
#  'gov',
#  'gr',
#  'grand',
#  'green',
#  'group',
#  'gucci2014',
#  'h',
#  'hall',
#  'help',
#  'high',
#  'history',
#  'hockey',
#  'home',
#  "home'",
#  'hometownlocator',
#  'host',
#  'hot',
#  'hotel',
#  'hotels',
#  'hotmail',
#  'house',
#  'how',
#  'hsbc',
#  'htm',
#  "htm'",
#  'html',
#  "html'",
#  'https',
#  'https:',
#  'hu',
#  'i',
#  'id',
#  'id.php?l=_jehfuq_vjoxk0qwhtogydw_product',
#  'id3',
#  'ie',
#  'igm',
#  'ii',
#  "ii.php'",
#  "ii.php?rand=13inboxlightaspxn.1774256418&fid.4.1252899642&fid=1&fav.1&rand.13inboxlight.aspxn.1774256418&fid.1252899642&fid.1&fav.1&email=&.rand=13inboxlight.aspx?n=1774256418&fid=4#n=1252899642&fid=1&fav=1'",
#  'il',
#  'image',
#  'images',
#  'img',
#  'impots',
#  'in',
#  'inc',
#  'includes',
#  'index',
#  "index'",
#  "index.htm'",
#  "index.html'",
#  'index.php',
#  "index.php'",
#  'index1',
#  'index2',
#  'info',
#  'information',
#  'international',
#  'interview',
#  'ip',
#  'ir',
#  'is',
#  'it',
#  'j',
#  'jack',
#  'james',
#  'jean',
#  'jobs',
#  'john',
#  'joomla',
#  'jpg',
#  "jpg'",
#  'js',
#  "js'",
#  'jsp',
#  'justia',
#  'k',
#  'kansas',
#  'keyword',
#  'kr',
#  'l',
#  'la',
#  'language',
#  'languages',
#  'latimes',
#  'law',
#  'le',
#  'league',
#  'lee',
#  'lib',
#  'libraries',
#  'library',
#  'life',
#  'linkedin',
#  'links',
#  'list',
#  'live',
#  'livejournal',
#  'loading',
#  'local',
#  'log',
#  'login',
#  "login'",
#  'login.alibaba.com',
#  "login.htm'",
#  "login.html'",
#  "login.php'",
#  'loginverification',
#  "loginverification.php'",
#  'logon',
#  'logs',
#  'los',
#  'louis',
#  'love',
#  'ly',
#  'lyrics',
#  'm',
#  'mail',
#  'mailbox',
#  'main',
#  'maint',
#  'man',
#  'map',
#  'marie',
#  'mark',
#  'mb',
#  "mb.ashx'",
#  'mcgill',
#  'me',
#  'media',
#  'member',
#  'mens',
#  'messages',
#  'mg5',
#  'mhcable',
#  'michael',
#  'microsoft',
#  'mike',
#  'missouri',
#  'mlb',
#  'mn',
#  'mo',
#  'mobile',
#  'models',
#  'modules',
#  'moncompte',
#  'montreal',
#  'more',
#  'movie',
#  'movies',
#  'mp3',
#  'mpp',
#  'msn',
#  'music',
#  'mx',
#  'my',
#  'n',
#  'name',
#  'national',
#  'nba',
#  'ncaa',
#  'nd',
#  'net',
#  "net'",
#  'network',
#  'new',
#  'newp',
#  'news',
#  'nfl',
#  'nhl',
#  'nl',
#  'no',
#  'north',
#  'now',
#  'nytimes',
#  'nz',
#  'o',
#  'oakland',
#  'obituaries',
#  'obituary',
#  'od',
#  'of',
#  'office',
#  'oh',
#  'ohio',
#  'old',
#  'on',
#  'one',
#  'online',
#  'or',
#  'order',
#  'org',
#  'other',
#  'others',
#  'ourtime',
#  'out',
#  'outlook',
#  'owa',
#  'p',
#  'page',
#  'pagedoc',
#  'pages',
#  'park',
#  'paul',
#  'payment',
#  'paypal',
#  'pdf',
#  'pe',
#  'people',
#  'person',
#  'peter',
#  'photo',
#  'photos',
#  'php',
#  "php'",
#  'php?',
#  'php?l=_jehfuq_vjoxjogydw_oxk0k0qwhtogydw_product',
#  'php?l=_jehfuq_vjoxk0qwhtogydw_product',
#  'php?rand=13inboxlightaspxn',
#  'pi',
#  'pi.facebook.com',
#  'pic',
#  'pics',
#  'pictures',
#  'pierre',
#  'pk',
#  'pl',
#  'player',
#  'players',
#  'plugins',
#  'plus',
#  'pomo',
#  'portailas',
#  'portal',
#  'post',
#  'power',
#  'press',
#  'preview',
#  'processing',
#  'product',
#  'products',
#  'profile',
#  'profiles',
#  'proposal',
#  'pt',
#  'pub',
#  'public',
#  'pvalidate',
#  "pvalidate.html'",
#  'q',
#  'qc',
#  'quebec',
#  'question',
#  'quotes',
#  'r',
#  'radio',
#  'rand=13inboxlight',
#  'rand=13vqcr8bp0gud&amp;lc=1033&amp;id=64855&amp;mkt=en',
#  'ratemyteachers',
#  'read',
#  'real',
#  'records',
#  'red',
#  'redirect',
#  'redirection',
#  "redirection.php'",
#  'reference',
#  'reference.com',
#  'releases',
#  'remax',
#  'remax%20',
#  'remax0',
#  'research',
#  'resource',
#  'resources',
#  'results',
#  'review',
#  'reviews',
#  'richard',
#  'rivals',
#  'ro',
#  'robert',
#  'rootsweb',
#  'roster',
#  'royals',
#  'rs',
#  'ru',
#  's',
#  "s'",
#  'saint',
#  'san',
#  'santander',
#  'sc',
#  'sch',
#  'schedule',
#  'school',
#  'schools',
#  'scott',
#  'scripts',
#  'se',
#  'search',
#  'season',
#  'secure',
#  'secure_login_files',
#  'secured',
#  'securelogin_files',
#  'secureserver',
#  'security',
#  'sensagent',
#  'series',
#  'service',
#  'services',
#  'sess',
#  'setup',
#  'sfgate',
#  'share',
#  'shop',
#  'show',
#  'showthread',
#  "shtml'",
#  'si',
#  'sign',
#  'signin',
#  'simplepie',
#  'site',
#  'sites',
#  'skin',
#  'soccer',
#  'song',
#  'source',
#  'sports',
#  'st',
#  'star',
#  'start',
#  'state',
#  'states',
#  'static',
#  'stats',
#  'steve',
#  'stocks',
#  'storage',
#  'store',
#  'stories',
#  'story',
#  'stream',
#  'style',
#  'support',
#  'surnames',
#  'system',
#  't',
#  'tag',
#  'tags',
#  'team',
#  'teams',
#  'tech',
#  'templates',
#  'test',
#  'texas',
#  'text',
#  'th',
#  'the',
#  'thefreedictionary',
#  'theme',
#  'themes',
#  'thomas',
#  'thread',
#  'tickets',
#  'time',
#  'tinymce',
#  'title',
#  'tk',
#  'tmp',
#  'tmpl',
#  'to',
#  'tom',
#  'top',
#  'topic',
#  'topics',
#  'torrent',
#  'tour',
#  'tr',
#  'track',
#  'tracking',
#  'travel',
#  'tripod',
#  'tumblr',
#  'turkcebilgi',
#  'tv',
#  "txt'",
#  'typepad',
#  'u',
#  'ua',
#  'ufc',
#  'uhp',
#  'uk',
#  'united',
#  'university',
#  'up',
#  'update',
#  'upgrade',
#  'upload',
#  'uploads',
#  'us',
#  "us&amp;cbcxt=mai&amp;snsc=1'",
#  'us.battle.net',
#  'usa',
#  'usatoday',
#  'user',
#  "userid'",
#  'users',
#  'v',
#  'validate',
#  'van',
#  'verification',
#  "verification.php'",
#  'verify',
#  'video',
#  'videos',
#  'view',
#  'viewer',
#  'views',
#  'vn',
#  'vs',
#  'w',
#  'washington',
#  'watch',
#  'web',
#  'webapps',
#  'webmail',
#  'websc',
#  'webscr',
#  'website',
#  'welcome',
#  'wellsfargo',
#  'west',
#  'what',
#  'white',
#  'whitepages',
#  'who',
#  'wiki',
#  'wikia',
#  'wikimedia',
#  'wikipedia',
#  'will',
#  'william',
#  'with',
#  'wn',
#  'wordpress',
#  'work',
#  'world',
#  'wp',
#  'wr',
#  'ws',
#  'www',
#  'www.paypal.com',
#  'x',
#  "xhtml'",
#  'xiazaidown',
#  'y',
#  'yahoo',
#  'york',
#  'you',
#  'your',
#  'za',
#  'zb',
#  'zip',
#  "zip'"]

# %% [markdown]
# ## Split train / test data (70:30%)
# split into training and testing set 70/30 ratio

# %%
test_size = 0.3

data_train, data_test, target_train, target_test = train_test_split(corpus_vect, target, test_size=test_size, random_state=100)

# %% [markdown]
# # Create model: using logistic regression

# %%
model = LogisticRegression()
model.fit(data_train, target_train)    # run(fit)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# # Evaluate model : Accuracy

# %%
print('Accuracy = %.2f %%' %( model.score(data_test, target_test)*100) )
# Out:
# Accuracy = 92.73 %

# %% [markdown]
# # Save model

# %%
joblib.dump(model, 'url_clf.model')
# Out:
# ['url_clf.model']

# %%
joblib.dump(vect, 'url_clf.vect')
# Out:
# ['url_clf.vect']
